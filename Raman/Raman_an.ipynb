# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x1 = pd.read_csv("Data/Spectrum_1/Spectrum1_Xdata.txt")
y1 = pd.read_csv("Data/Spectrum_1/Echip thinn raman--Spectrum--008--Spec.Data 1 (Y-Axis).txt")

x2 = pd.read_csv("Data/Spectrum 2/Echip thinn raman--Spectrum--009--Spec.Data 1 (X-Axis).txt")
y2 = pd.read_csv("Data/Spectrum 2/Echip thinn raman--Spectrum--009--Spec.Data 1 (Y-Axis).txt")

x3=pd.read_csv("Data/Spectrum 3/Echip thinn raman--Spectrum--010--Spec.Data 1 (X-Axis).txt")
y3=pd.read_csv("Data/Spectrum 3/Echip thinn raman--Spectrum--010--Spec.Data 1 (Y-Axis).txt")

x4 = pd.read_csv("Data/Spectrum 4/Echip thinn raman--Spectrum--011--Spec.Data 1 (X-Axis).txt")
y4 = pd.read_csv("Data/Spectrum 4/Echip thinn raman--Spectrum--011--Spec.Data 1 (Y-Axis).txt")

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.plot(x3,y3)
plt.plot(x4,y4)

plt.vlines([406,384.5],0,50000,linestyles=":")

plt.xlim((370,425))
plt.show()
print(406-384.5)
print("About 2 layers for G10")
# Out:
# 21.5
# About 2 layers for G10
